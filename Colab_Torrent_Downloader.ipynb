# %% [markdown]
# # 📥 Torrent Downloader to Google Drive
#
# This notebook lets you download torrent files using a magnet link **directly to your Google Drive**.
#
# 👉 Just run each cell step by step.

# %% [markdown]
# ## 🔗 1️⃣ Mount Google Drive

# %%
#@markdown Run this cell to mount your Drive Account
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## ⚙️ 2️⃣ Install aria2c

# %%
#@markdown Run Cell to Install aria2c & any extra required additional dependencies
# !apt-get install -y aria2
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 35 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-ares2 amd64 1.18.1-1ubuntu0.22.04.3 [45.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libaria2-0 amd64 1.36.0-1 [1,086 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 aria2 amd64 1.36.0-1 [381 kB]
# Fetched 1,513 kB in 2s (665 kB/s)
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 126111 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# ...

# %% [markdown]
# ## 🗂️ 3️⃣ Create Download Folder in Drive
#
# This will create a folder named `Colab_Torrent_Downloads` inside your Drive.

# %%
# @title
import os

download_folder = '/content/drive/My Drive/Colab_Torrent_Downloads'
os.makedirs(download_folder, exist_ok=True)

print(f"Download folder is set to: {download_folder}")
# Out:
# Download folder is set to: /content/drive/My Drive/Colab_Torrent_Downloads

# %% [markdown]
# ## 🔑 4️⃣ Enter Magnet Link
#
# Use the field below to paste your **magnet link**.

# %%
magnet_link = "magnet:?xt=urn:btih:7D5ZYLEE6QUCJ4HXCJGD26R6VKFZJYON&dn=PeppermintOS-Debian-64_loaded.iso&xl=2430320640&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce" #@param {type:"string"}

print(f"Magnet link set to: {magnet_link}")
# Out:
# Magnet link set to: magnet:?xt=urn:btih:7D5ZYLEE6QUCJ4HXCJGD26R6VKFZJYON&dn=PeppermintOS-Debian-64_loaded.iso&xl=2430320640&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce

# %% [markdown]
# ## ⏬ 5️⃣ Start Download

# %%
#@markdown Run This Cell to Start Downloading the Torrent to your Drive folder
if magnet_link.strip() == "":
  print("⚠️ Please enter a valid magnet link above!")
else:
  print("📥 Downloading torrent...")
  # !aria2c --dir="{download_folder}" --seed-time=0 "{magnet_link}"
  print(f"✅ Download complete! Files saved in: {download_folder}")
# Out:
# 📥 Downloading torrent...
#
# 06/14 15:53:16 [NOTICE] Downloading 1 item(s)
#
# 06/14 15:53:16 [ERROR] Exception caught while loading DHT routing table from /root/.cache/aria2/dht.dat
# Exception: [DHTRoutingTableDeserializer.cc:82] errorCode=1 Failed to load DHT routing table from /root/.cache/aria2/dht.dat
#
# 06/14 15:53:16 [NOTICE] IPv4 DHT: listening on UDP port 6990
#
# 06/14 15:53:16 [NOTICE] IPv4 BitTorrent: listening on TCP port 6884
#
# 06/14 15:53:16 [ERROR] IPv6 BitTorrent: failed to bind TCP port 6884
# Exception: [SocketCore.cc:312] errorCode=1 Failed to bind a socket, cause: Name or service not known
#
# 06/14 15:53:20 [NOTICE] Download complete: [MEMORY][METADATA]PeppermintOS-Debian-64_loaded.iso
#
# 06/14 15:53:20 [NOTICE] Allocating disk space. Use --file-allocation=none to disable it. See --file-allocation option in man page for more details.
#  *** Download Progress Summary as of Sat Jun 14 15:54:16 2025 ***
# =
# ...

# %% [markdown]
# ## ✅ **Done!**
